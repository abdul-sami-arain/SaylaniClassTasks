# %%
import numpy as np
from PIL import Image

# %% [markdown]
# # Image Processing Using Numpy:

# %% [markdown]
# ## RGB to Greyscale:

# %%
image = Image.open('parrots.jpg') # import image using python imaging library

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=980x490 at 0x214C8869820>

# %%
imageData1 = np.asarray(image) # Convert the image into array
imageData1
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [  1,   4,   0],
#         [  1,   0,  20],
#         [  2,   0,   5]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [253, 253, 253],
#         ...,
#         [  6,  12,   0],
#         [  0,   0,  11],
#         [  4,   2,   3]],
#
#        [[254, 254, 254],
#         [252, 252, 252],
#         [250, 250, 250],
#         ...,
#         [ 76,  83,  31],
#         [ 14,  12,  13],
#         [  1,   1,   0]],
#
#        ...,
#
#        [[241, 241, 241],
#         [233, 233, 233],
#         [220, 220, 220],
#         ...,
#         [251, 251, 251],
#         [255, 255, 255],
#         [252, 252, 252]],
#
#        [[244, 244, 244],
#         [239, 239, 239],
#         [231, 231, 231],
#         ...,
#         [250, 250, 250],
#         [252, 252, 252],
#         [254, 254, 254]],
#
#        [[249, 249, 249],
#         [245, 245, 245],
#         [239, 239, 239],
# ...

# %%
imageData2 = imageData1[...,0] # select all x , y values and oth index value of z 
imageData2
# Out:
# array([[255, 255, 254, ...,   1,   1,   2],
#        [255, 254, 253, ...,   6,   0,   4],
#        [254, 252, 250, ...,  76,  14,   1],
#        ...,
#        [241, 233, 220, ..., 251, 255, 252],
#        [244, 239, 231, ..., 250, 252, 254],
#        [249, 245, 239, ..., 253, 255, 255]], dtype=uint8)

# %%
image2 = Image.fromarray(imageData2) # creating image from array

# %%
image2
# Out:
# <PIL.Image.Image image mode=L size=980x490 at 0x214C93D21C0>
